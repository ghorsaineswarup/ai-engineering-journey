# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000)

# %%
d_r = 2.5 * t

# %%
d_s = 3 * (t-5)

# %%
fig, ax = plt.subplots()
plt.title('A Bank Robber Caught')
plt.xlabel('time (in minutes)')
plt.ylabel('distane in kilometer')
ax.set_xlim([0,40])
ax.set_ylim([0,100])
ax.plot(t, d_r, c='green')
ax.plot(t, d_s, c='brown')
plt.axvline(x=30, color='purple', linestyle='--')
__ = plt.axhline(y=75, color='purple', linestyle='--')

# %%
#scalars (Rank 0 Tensors) in base python

# %%
x=25
x
# Out:
# 25

# %%
type(x)
# Out:
# int

# %%
y=3

# %%
py_sum=x+y
py_sum
# Out:
# 28

# %%
type(py_sum)
# Out:
# int

# %%
x_float = 25.0
float_sum = x_float + y
float_sum
# Out:
# 28.0

# %%
type(float_sum)
# Out:
# float

# %%
#Vectors (Rank 1 Tensors) in NumPy

# %%
x = np.array([25, 2, 5])
x
# Out:
# array([25,  2,  5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# np.int64(25)

# %%
type(x[0])
# Out:
# numpy.int64

# %%
#vector transposing

# %%
x_t = x.T  #transposing a 1-D array has no effect......
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
#but when we use nested "matrx-style" brackets it does change i mean it does transpose
y = np.array([[25, 2, 5]])
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape # so it has 3 rows and 1 column
# Out:
# (3, 1)

# %%
#column vector can be transposed back to row vector:
y_t.T
# Out:
# array([[25,  2,  5]])

# %%
y_t.T.shape
# Out:
# (1, 3)

# %%
#zero vectors 
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %%
#L^2 NORM

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)**(1/2)  #this method is lenghty we can basically use build in norm method.
# Out:
# 25.573423705088842

# %%
np.linalg.norm(x)
# Out:
# np.float64(25.573423705088842)

# %%
#SQUARED L2 NORM

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)
# Out:
# 654

# %%
np.dot(x,x)
# Out:
# np.int64(654)

# %%
#L^1 NORM

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.abs(25) + np.abs(2) + np.abs(5)
# Out:
# np.int64(32)

# %%
#L^infinty NORM

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.max([np.abs(25), np.abs(2), np.abs(5)])
# Out:
# np.int64(25)

# %%
#orthogonal vectors

# %%
i = np.array([1,0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0,1])
j
# Out:
# array([0, 1])

# %%
np.dot(i, j)
# Out:
# np.int64(0)
