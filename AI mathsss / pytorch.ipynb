# %%
import torch

# %%
x_pt = torch.tensor(25) # type specification optional, e.g.: dtype=torch.float16
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([3])

# %%
#vectors in pytorch

# %%
x_pt = torch.tensor([25, 2, 3])
x_pt
# Out:
# tensor([25,  2,  3])
